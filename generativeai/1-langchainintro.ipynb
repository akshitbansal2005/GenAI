# %% [markdown]
# # Langchain Version V1

# %%
import langchain
print(langchain.__version__)
# Out:
# 1.3.14

# %%
import os
from dotenv import load_dotenv
load_dotenv()

# os.environ["OPENAI_API_KEY"]=os.getenv("OPENAI_API_KEY")
os.environ["GROQ_API_KEY"]=os.getenv("GROQ_API_KEY")

# %% [markdown]
# # GenAi Applications Using OpenAI Model

# %%
from langchain_groq import ChatGroq
model = ChatGroq(model="llama-3.1-8b-instant")
model
# Out:
# ChatGroq(metadata={'lc_versions': {'langchain-core': '1.4.9', 'langchain': '1.3.14'}}, output_version=None, profile={'name': 'Llama 3.1 8B Instant', 'release_date': '2024-07-23', 'last_updated': '2024-07-23', 'open_weights': True, 'max_input_tokens': 131072, 'max_output_tokens': 131072, 'text_inputs': True, 'image_inputs': False, 'audio_inputs': False, 'video_inputs': False, 'text_outputs': True, 'image_outputs': False, 'audio_outputs': False, 'video_outputs': False, 'reasoning_output': False, 'tool_calling': True, 'attachment': False, 'temperature': True}, client=<groq.resources.chat.completions.Completions object at 0x000001B740322470>, async_client=<groq.resources.chat.completions.AsyncCompletions object at 0x000001B7404697B0>, model_name='llama-3.1-8b-instant', model_kwargs={}, groq_api_key=SecretStr('**********'), groq_api_base=None, groq_proxy=None)

# %%
# First GenAI Application
response=model.invoke("write me an essay on AI")
response
# Out:
# AIMessage(content='**The Rise of Artificial Intelligence: A Double-Edged Sword**\n\nArtificial Intelligence (AI) has become a ubiquitous term in modern technology, with its applications ranging from voice assistants and virtual assistants to self-driving cars and medical diagnosis. The rapid advancement of AI has revolutionized various industries, transforming the way we live, work, and interact with one another. However, the increasing reliance on AI also raises concerns about its potential consequences, both positive and negative.\n\nOn the one hand, AI has the potential to greatly benefit society. One of the most significant advantages of AI is its ability to automate routine and repetitive tasks, freeing up human resources for more complex and creative work. For instance, AI-powered chatbots and virtual assistants have made it easier for people to access information and perform tasks, such as setting reminders and making appointments, without having to physically interact with a 
# ...

# %%
print(response.content)
# Out:
# **The Rise of Artificial Intelligence: A Double-Edged Sword**
#
# Artificial Intelligence (AI) has become a ubiquitous term in modern technology, with its applications ranging from voice assistants and virtual assistants to self-driving cars and medical diagnosis. The rapid advancement of AI has revolutionized various industries, transforming the way we live, work, and interact with one another. However, the increasing reliance on AI also raises concerns about its potential consequences, both positive and negative.
#
# ...

# %%
from langchain_groq import ChatGroq
model = ChatGroq(model="llama-3.1-8b-instant")
response = model.invoke("hello guys, how are you?")
response
# Out:
# AIMessage(content="Hello. I'm just a computer program, so I don't have feelings or emotions like humans do. However, I'm functioning properly and ready to assist you with any questions or tasks you may have. How can I help you today?", additional_kwargs={}, response_metadata={'token_usage': {'completion_tokens': 49, 'prompt_tokens': 42, 'total_tokens': 91, 'completion_time': 0.049852774, 'completion_tokens_details': None, 'prompt_time': 0.00193753, 'prompt_tokens_details': None, 'queue_time': 0.04902452, 'total_time': 0.051790304}, 'model_name': 'llama-3.1-8b-instant', 'system_fingerprint': 'fp_4387d3edbb', 'service_tier': 'on_demand', 'finish_reason': 'stop', 'logprobs': None, 'model_provider': 'groq'}, id='lc_run--019f76df-7e6c-7f61-84fe-c7243e91ce74-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 42, 'output_tokens': 49, 'total_tokens': 91})

# %%
print(response.content)
# Out:
# Hello. I'm just a computer program, so I don't have feelings or emotions like humans do. However, I'm functioning properly and ready to assist you with any questions or tasks you may have. How can I help you today?

# %% [markdown]
# LLM Model Integration With Google Gemini

# %%
os.environ["GROQ_API_KEY"]=os.getenv("GROQ_API_KEY")

# %%
from langchain.chat_models import init_chat_model
model= init_chat_model("google_genai:gemini-3.5-flash")
response=model.invoke("write me an essay on AI")
print(response.content)
# Out:
# [{'type': 'text', 'text': '**Title:** The Double-Edged Sword of Progress: Navigating the Era of Artificial Intelligence\n\nArtificial Intelligence (AI) is no longer a concept confined to the pages of science fiction novels or the silver screens of Hollywood. Today, it is an ambient, defining force of the twenty-first century. From the algorithms that curate our social media feeds to the neural networks diagnosing complex medical conditions, AI has integrated itself into the fabric of daily life. As a technology that mimics cognitive functions such as learning, reasoning, and problem-solving, AI represents one of humanity’s greatest achievements. However, this rapid technological leap is a double-edged sword. While AI offers unprecedented opportunities to revolutionize industries and solve complex global challenges, it also presents profound ethical, economic, and existential risks that demand proactive governance.\n\nTo understand the current state of AI, one must appreciate its rapi
# ...

# %%
from langchain_google_genai import ChatGoogleGenerativeAI
model=ChatGoogleGenerativeAI(model= "gemini-3.5-flash")
response=model.invoke("write me an essay on AI")
print(response.content)
# Out:
# [{'type': 'text', 'text': '**Title:** Minds and Machines: The Promise and Peril of Artificial Intelligence\n\nIn the span of just a few decades, Artificial Intelligence (AI) has transitioned from the realm of science fiction into the fabric of daily life. Once conceptualized as sentient robots in futuristic novels, AI is now embedded in our smartphones, healthcare systems, financial markets, and creative industries. Today, we stand at a critical juncture in human history, navigating a technological revolution driven by machine learning, neural networks, and generative models. While Artificial Intelligence holds unprecedented potential to revolutionize human capability and solve complex global challenges, its rapid integration necessitates rigorous ethical frameworks to mitigate risks to employment, privacy, and human agency.\n\nTo understand the impact of AI, one must first understand its evolution. Early AI research in the mid-20th century relied on "rule-based" systems—machines pro
# ...

# %% [markdown]
# ### GROQ MODEL INTEGRATION

# %%
import os
from langchain.chat_models import init_chat_model
os.environ["GROQ_API_KEY"] =os.getenv("GROQ_API_KEY")

model=init_chat_model("groq:llama-3.1-8b-instant")
response=model.invoke("write me a joke on machine learning")
print(response.content)
# Out:
# Why did the machine learning model break up with its significant other?
#
# Because it realized it was in a neural network of toxic relationships and needed to update its algorithm for a healthier attachment style.

# %%
import os
from langchain_groq import ChatGroq

model=ChatGroq(model="qwen/qwen3.6-27b")
response=model.invoke("write me a joke on machine learning")
response
# Out:
# AIMessage(content='\n<think>\nHere\'s a thinking process:\n\n1.  **Analyze User Request:**\n   - **Topic:** Machine Learning\n   - **Format:** Joke\n   - **Goal:** Create a funny, relevant, and accurate joke about machine learning\n\n2.  **Identify Key ML Concepts for Humor:**\n   - Training data, overfitting, underfitting, bias/variance, neural networks, backpropagation, loss function, epochs, validation/test sets, AI/ML misconceptions, "garbage in, garbage out", model deployment, hyperparameter tuning, black box, etc.\n\n3.  **Brainstorming Joke Structures:**\n   - *Punchline-based:* Setup + Punchline\n   - *Dialogue:* Two people/AI talking\n   - *Analogy:* Compare ML to everyday situations\n   - *Wordplay:* Puns on ML terms\n\n   Let\'s try a few approaches:\n   - *Overfitting joke:* Why did the machine learning model get kicked out of the party? Because it memorized everyone\'s drink order but couldn\'t handle a new guest. (A bit weak)\n   - *Training/Testing joke:* How many mach
# ...

# %%
response.content
# Out:
# '\n<think>\nHere\'s a thinking process:\n\n1.  **Analyze User Request:**\n   - **Topic:** Machine Learning\n   - **Format:** Joke\n   - **Goal:** Create a humorous, relevant, and clever joke about machine learning\n\n2.  **Identify Key Machine Learning Concepts:**\n   - Training data, overfitting, underfitting, bias/variance\n   - Neural networks, layers, activation functions\n   - Supervised vs unsupervised learning\n   - Models, algorithms, predictions, accuracy, loss functions\n   - Data preprocessing, feature engineering\n   - AI vs human intelligence, "learning" from mistakes\n\n3.  **Brainstorming Joke Structures:**\n   - Pun-based\n   - Q&A format\n   - Story/analogy format\n   - Play on words related to ML terms\n\n   Let\'s try Q&A format first (classic joke structure):\n   *Why did the machine learning model break up with its partner?*\n   *Because it kept overfitting to every little problem!*\n\n   Check: Relatable to ML folks? Yes. Clever? Moderately. Could be better.\n\n
# ...

# %% [markdown]
# ### streaming and batch
#
# STREAMING
# Most models can stream their ouput content while it is being generated. By displaying output progressively streaming imprves user experience for longer responses. calling stream() returns an iterator that yield output chunks as they are produced.You can use a loop to process each chunk in real time.

# %%
for chunk in model.stream("write me a 500 words paragraph on AI"):
    print(chunk.text, end="", flush=True)
# Out:
# <think>
# Here's a thinking process:
#
# 1.  **Analyze User Request:**
#    - **Topic:** AI (Artificial Intelligence)
#    - **Length:** 500 words
#    - **Format:** Single paragraph
#    - **Goal:** Write a comprehensive, coherent, and engaging paragraph about AI.
#
# 2.  **Key Themes/Points to Cover (Mental Outline):**
#    - Definition & evolution of AI
#    - Core technologies/methods (machine learning, neural networks, etc.)
#    - Applications across industries
#    - Societal impact (positive & negative)
#    - Ethical considerations & future outlook
#    - Need to weave these into a single, flowing paragraph of exactly/around 500 words.
#
# 3.  **Drafting - Mental Refinement (Word Count Monitoring):**
#    I'll write carefully, keeping track of the flow and approximate word count. I'll aim for academic yet accessible tone, avoiding bullet points or line breaks since it must be one paragraph.
#
#    *Start drafting:*
# ...

# %%
model.invoke("Why do parrots have colorful feathers?")
# Out:
# AIMessage(content='\n<think>\nHere\'s a thinking process:\n\n1.  **Understand User Question**: The user asks "Why do parrots have colorful feathers?" This is a biological/evolutionary question about parrot feather coloration.\n\n2.  **Identify Key Concepts**:\n   - Parrot feather colors (red, blue, green, yellow, etc.)\n   - Evolutionary reasons (sexual selection, camouflage, species recognition, social signaling)\n   - Biological mechanisms (pigments vs. structural coloration)\n   - Ecological context (tropical habitats, diet, environment)\n\n3.  **Break Down the Answer**:\n   - **Evolutionary/Functional Reasons**:\n     - Sexual selection (attracting mates)\n     - Species recognition (finding mates, avoiding hybridization)\n     - Social signaling/status within flocks\n     - Camouflage/counter-illumination (some argue bright colors blend in dappled forest light)\n     - Warning/aposematism (less common in parrots, but some link to diet/toxins)\n   - **Biological Mechanisms**:\n  
# ...

# %%
for chunk in model.stream("Why do parrots have colorful feathers?"):
    print(chunk.text, end="|", flush=True)
# Out:
# |
# <think>
# |Here|'s| a| thinking| process|:|
#
# |1|.| | **|Under|stand| User| Question|**:| The| user|
#  asks| "|Why| do| par|rots| have| colorful| feathers|?"| This| is| a| straightforward| biological|/|ev|olution|ary| question| about| par|rot| plum|age| color|ation|.|
#
# |2|.| | **|Ident|ify| Key| Concepts|**:|
# |  | -| Par|rot| feather| color|ation|
# |  | -| Evolution|ary| purposes| of| bright| colors|
# |  | -| Biological| mechanisms| (|pig|ments|,| structural| colors|)|
# |  | -| Ec|ological|/social| functions| (|m|ating|,| communication|,| camouflage|,| species| recognition|)|
# |  | -| Trade|-offs| (|pred|ation| risk| vs|.| benefits|)|
#
# |3|.| | **|Brain|storm|ing|/|Rec|all| Knowledge|**:|
# |  | -| *|P|ig|ments|*:| Ps|itt|ac|of|ul|v|ins| (|unique| to| par|rots|),| car|oten|oids| (|from| diet|),| melan|ins| (|bl|acks|,| brow|ns|,| some| red|s|/y|ell|ows|)|
# ...

# %% [markdown]
# ### Batch
#
# Batching a collection of independent request to a model can significantly imprpve performance and reduce cost, as the processing can be done parallel.

# %%
responses=model.batch(
    [
        "Why do parrots have colorful feathers?"
        "Why do airplanes fly?"
        "What is quantum computing?"
    ]
)
for response in responses:
    print(response)
# Out:
# content='\n<think>\nHere\'s a thinking process:\n\n1.  **Analyze User Input:**\n   - Three distinct questions:\n     a. Why do parrots have colorful feathers?\n     b. Why do airplanes fly?\n     c. What is quantum computing?\n   - Each requires a clear, concise, scientifically accurate explanation tailored to a general audience.\n   - I should address each question separately, maintain a logical flow, and ensure accuracy.\n\n2.  **Question 1: Why do parrots have colorful feathers?**\n   - *Key concepts:* Evolution, natural/sexual selection, communication, camouflage, health indicators, pigment types (carotenoids, porphyrins, structural colors).\n   - *Explanation structure:*\n     - Evolutionary purpose: mate attraction (sexual selection), social communication, species recognition.\n     - Biological mechanism: pigments (diet-derived carotenoids, synthesized porphyrins) and structural colors (light scattering/interference).\n     - Additional factors: health/fitness indicators (brig
# ...

# %%
model.batch(
    [
        "Why do parrots have colorful feathers?"
        "Why do airplanes fly?"
        "What is quantum computing?"],
config={
    'max_concurrency':5, #limit to 5 parallel cells 
    }
)
# Out:
# [AIMessage(content='\n<think>\nHere\'s a thinking process:\n\n1.  **Analyze User Input:**\n   - The user asks three distinct, unrelated questions in a single prompt:\n     a. Why do parrots have colorful feathers?\n     b. Why do airplanes fly?\n     c. What is quantum computing?\n   - I need to answer each question clearly, concisely, and accurately, while maintaining a structured format.\n\n2.  **Deconstruct Each Question:**\n\n   **Question 1: Why do parrots have colorful feathers?**\n   - *Key concepts:* Evolution, natural selection, sexual selection, camouflage/signaling, pigments/structural colors.\n   - *Scientific explanation:* \n     - Coloration serves multiple purposes: mate attraction (sexual selection), species recognition, social communication, and sometimes camouflage (though less common in bright parrots).\n     - Colors come from pigments (carotenoids from diet, porphyrins) and structural colors (light scattering/refraction in feather microstructures).\n     - Evolut
# ...
